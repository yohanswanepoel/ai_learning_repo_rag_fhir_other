# %%
# !pip install --upgrade pymilvus openai requests tqdm
# !pip install torch
# !pip install llama-index
# !pip install transformers
# !pip install sentence-transformers 


# !pip install llama-index-embeddings-huggingface 
# !pip install llama-index-embeddings-instructor
# Out:
# Requirement already satisfied: pymilvus in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: openai in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (1.58.1)
# Requirement already satisfied: requests in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: setuptools>69 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (75.6.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (5.29.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (2.2.3)
# Requirement already satisfied: milvus-lite>=2.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (2.10.4)
# Requirement already satisfied: sniffio in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: six>=1.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Requirement already satisfied: torch in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: filelock in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: llama-index in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (0.12.8)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.12.8)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.3.12)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.58.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.8->llama-index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (3.11.11)
# Requirement already satisfied: dataclasses-json in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (2024.12.0)
# Requirement already satisfied: httpx in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (3.4.2)
# Requirement already satisfied: numpy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.8->llama-index) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.7)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.5.18)
# Requirement already satisfied: click in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.8->llama-index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: certifi<2025.0.0,>=2024.7.4 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-cloud>=0.1.5->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2024.12.14)
# Requirement already satisfied: anyio in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.8->llama-index) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.8->llama-index) (1.0.7)
# Requirement already satisfied: idna in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.8->llama-index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.8->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.8.2)
# Requirement already satisfied: sniffio in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.8->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.8->llama-index) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.8->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.8->llama-index) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.8->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.8->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.8->llama-index) (3.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.8->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: transformers in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (4.47.1)
# Requirement already satisfied: filelock in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: sentence-transformers in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (4.47.1)
# Requirement already satisfied: tqdm in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: numpy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (2.2.1)
# Requirement already satisfied: scikit-learn in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (0.27.0)
# Requirement already satisfied: Pillow in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: setuptools in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.12.14)
# Requirement already satisfied: llama-index-embeddings-huggingface in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (0.4.0)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (0.12.8)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-huggingface) (2.7.0)
# Requirement already satisfied: filelock in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.11.11)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.36)
# Requirement already satisfied: dataclasses-json in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.10.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.17.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: scipy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.18.3)
# Requirement already satisfied: click in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.1.8)
# Requirement already satisfied: joblib in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: jinja2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.5)
# Requirement already satisfied: setuptools in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.23.2)
# Requirement already satisfied: anyio in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.0.2)
# Requirement already satisfied: llama-index-embeddings-instructor in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: instructorembedding<2.0.0,>=1.0.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-instructor) (1.0.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-instructor) (0.12.8)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-instructor) (2.7.0)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-embeddings-instructor) (2.5.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.11.11)
# Requirement already satisfied: dataclasses-json in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2024.12.0)
# Requirement already satisfied: httpx in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.9.1)
# Requirement already satisfied: numpy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.9.0)
# Requirement already satisfied: wrapt in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.17.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (4.47.1)
# Requirement already satisfied: scikit-learn in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (1.6.0)
# Requirement already satisfied: scipy in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.27.0)
# Requirement already satisfied: filelock in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (3.16.1)
# Requirement already satisfied: jinja2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (3.1.5)
# Requirement already satisfied: setuptools in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.18.3)
# Requirement already satisfied: packaging>=20.9 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (24.2)
# Requirement already satisfied: click in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (8.1.8)
# Requirement already satisfied: joblib in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.1.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.23.2)
# Requirement already satisfied: anyio in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/jswanepo/Development/ai_learning/venv/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.3.1)

# %%
import glob
import json, sys

sys.path.insert(1,'./utils/')
from FHIR_to_graph import resource_to_node, resource_to_edges, resource_to_string

# %%
with open('fhir_resources/Cassy835_Kohler843_01b6ca2a-b591-4560-9014-c37e1565f0cd.json') as raw:
    bundle = json.load(raw)
    for entry in bundle['entry']:
        resource_type = entry['resource']['resourceType']
        if resource_type != 'Provenance':
            print("---------------------------------------------------------------")
            print(resource_type)
            print("---------------------------------------------------------------")
            flattened_resource = resource_to_string(entry['resource']) # This is a dictionary
            print(flattened_resource['text'])
            print(json.dumps(flattened_resource))
# Out:
# ---------------------------------------------------------------
# Patient
# ---------------------------------------------------------------
# The type of information in this entry is patient. The name use for this patient is official. The name family for this patient is Kohler843. The name given for this patient is Cassy835. The telecom system for this patient is phone. The telecom value for this patient is 555-292-5994. The telecom use for this patient is home. The gender for this patient is female. The birth date for this patient is 2019-07-23. The address line for this patient is 949 Crist Burg Unit 59. The address city for this patient is Plymouth. The address state for this patient is Massachusetts. The address postalCode for this patient is 02360. The address country for this patient is US. The marital status for this patient is Never Married. The multiple birth boolean for this patient is False. The communication language for this patient is English.
# {"resource_type": "Patient", "id": "a0917f1f-b1b9-4656-a48e-851bf15fede3", "extension_0_url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-race", "extension_0_extension_0_url": "ombCategory", "extension_0_extension_0_value_coding_system": "urn:oid:2.16.840.1.113883.6.238", "extension_0_extension_0_value_coding_code": "2106-3", "extension_0_extension_0_value_coding_display": "White", "extension_0_extension_1_url": "text", "extension_0_extension_1_value_string": "White", "extension_1_url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity", "extension_1_extension_0_url": "ombCategory", "extension_1_extension_0_value_coding_system": "urn:oid:2.16.840.1.113883.6.238", "extension_1_extension_0_value_coding_code": "2186-5", "extension_1_extension_0_value_coding_display": "Not Hispanic or Latino", "extension_1_extension_1_url": "text", "extension_1_extension_1_value_string": "Not Hispanic or Latino", "extension_2_url": "http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName", "extension_2_value_string": "Mercedez75 Williamson769", "extension_3_url": "http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex", "extension_3_value_code": "F", "extension_4_url": "http://hl7.org/fhir/StructureDefinition/patient-birthPlace", "extension_4_value_address_city": "Chicopee", "extension_4_value_address_state": "Massachusetts", "extension_4_value_address_country": "US", "extension_5_url": "http://synthetichealth.github.io/synthea/disability-adjusted-life-years", "extension_5_value_decimal": 0.0, "extension_6_url": "http://synthetichealth.github.io/synthea/quality-adjusted-life-years", "extension_6_value_decimal": 0.0, "identifier_0_system": "https://github.com/synthetichealth/synthea", "identifier_0_value": "01b6ca2a-b591-4560-9014-c37e1565f0cd", "identifier_1_type_coding_0_system": "http://terminology.hl7.org/CodeSystem/v2-0203", "identifier_1_type_coding_0_code": "MR", "identifier_1_type_coding_0_display": "Medical Record Number", "identifier_1_type_text": "Medical Record Number", "identifier_1_system": "http://hospital.smarthealthit.org", "identifier_1_value": "01b6ca2a-b591-4560-9014-c37e1565f0cd", "identifier_2_type_coding_0_system": "http://terminology.hl7.org/CodeSystem/v2-0203", "identifier_2_type_coding_0_code": "SS", "identifier_2_type_coding_0_display": "Social Security Number", "identifier_2_type_text": "Social Security Number", "identifier_2_system": "http://hl7.org/fhir/sid/us-ssn", "identifier_2_value": "999-86-3498", "name_0_use": "official", "name_0_family": "Kohler843", "name_0_given_0": "Cassy835", "telecom_0_system": "phone", "telecom_0_value": "555-292-5994", "telecom_0_use": "home", "gender": "female", "birth_date": "2019-07-23", "address_0_extension_0_url": "http://hl7.org/fhir/StructureDefinition/geolocation", "address_0_extension_0_extension_0_url": "latitude", "address_0_extension_0_extension_0_value_decimal": 41.96480685994205, "address_0_extension_0_extension_1_url": "longitude", "address_0_extension_0_extension_1_value_decimal": -70.55281629965809, "address_0_line_0": "949 Crist Burg Unit 59", "address_0_city": "Plymouth", "address_0_state": "Massachusetts", "address_0_postal_code": "02360", "address_0_country": "US", "marital_status_coding_0_system": "http://terminology.hl7.org/CodeSystem/v3-MaritalStatus", "marital_status_coding_0_code": "S", "marital_status_coding_0_display": "Never Married", "marital_status_text": "Never Married", "multiple_birth_boolean": false, "communication_0_language_coding_0_system": "urn:ietf:bcp:47", "communication_0_language_coding_0_code": "en-US", "communication_0_language_coding_0_display": "English", "communication_0_language_text": "English", "text": "The type of information in this entry is patient. The name use for this patient is official. The name family for this patient is Kohler843. The name given for this patient is Cassy835. The telecom system for this patient is phone. The telecom value for this patient is 555-292-5994. The tele ...
# ---------------------------------------------------------------
# Organization
# ---------------------------------------------------------------
# The type of information in this entry is organization. The active for this organization is True. The type of this organization is Healthcare Provider. The name for this organization is BAY STATE PHYSICAL THERAPY OF RANDOLPH PC. The telecom system for this organization is phone. The telecom value for this organization is 508-833-5180. The address line for this organization is 7 HERRING POND RD. The address city for this organization is CEDARVILLE. The address state for this organization is MA. The address postalCode for this organization is 02360-6903. The address country for this organization is US.
# {"resource_type": "Organization", "id": "a0a14713-50c4-3818-b0cb-8c2047f1458c", "identifier_0_system": "https://github.com/synthetichealth/synthea", "identifier_0_value": "a0a14713-50c4-3818-b0cb-8c2047f1458c", "active": true, "type_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/organization-type", "type_0_coding_0_code": "prov", "type_0_coding_0_display": "Healthcare Provider", "type_0_text": "Healthcare Provider", "name": "Organization", "telecom_0_system": "phone", "telecom_0_value": "508-833-5180", "address_0_line_0": "7 HERRING POND RD", "address_0_city": "CEDARVILLE", "address_0_state": "MA", "address_0_postal_code": "02360-6903", "address_0_country": "US", "text": "The type of information in this entry is organization. The active for this organization is True. The type of this organization is Healthcare Provider. The name for this organization is BAY STATE PHYSICAL THERAPY OF RANDOLPH PC. The telecom system for this organization is phone. The telecom value for this organization is 508-833-5180. The address line for this organization is 7 HERRING POND RD. The address city for this organization is CEDARVILLE. The address state for this organization is MA. The address postalCode for this organization is 02360-6903. The address country for this organization is US."}
# ---------------------------------------------------------------
# Practitioner
# ---------------------------------------------------------------
# The type of information in this entry is practitioner. The active for this practitioner is True. The name family for this practitioner is Schamberger479. The name given for this practitioner is Robena997. The name prefix for this practitioner is Dr.. The telecom system for this practitioner is email. The telecom value for this practitioner is Robena997.Schamberger479@example.com. The telecom use for this practitioner is work. The address line for this practitioner is 7 HERRING POND RD. The address city for this practitioner is CEDARVILLE. The address state for this practitioner is MA. The address postalCode for this practitioner is 02360-6903. The address country for this practitioner is US. The gender for this practitioner is female.
# {"resource_type": "Practitioner", "id": "0000016d-3a85-4cca-0000-000000016be8", "identifier_0_system": "http://hl7.org/fhir/sid/us-npi", "identifier_0_value": "93160", "active": true, "name_0_family": "Schamberger479", "name_0_given_0": "Robena997", "name_0_prefix_0": "Dr.", "telecom_0_system": "email", "telecom_0_value": "Robena997.Schamberger479@example.com", "telecom_0_use": "work", "address_0_line_0": "7 HERRING POND RD", "address_0_city": "CEDARVILLE", "address_0_state": "MA", "address_0_postal_code": "02360-6903", "address_0_country": "US", "gender": "female", "text": "The type of information in this entry is practitioner. The active for this practitioner is True. The name family for this practitioner is Schamberger479. The name given for this practitioner is Robena997. The name prefix for this practitioner is Dr.. The telecom system for this practitioner is email. The telecom value for this practitioner is Robena997.Schamberger479@example.com. The telecom use for this practitioner is work. The address line for this practitioner is 7 HERRING POND RD. The address city for this practitioner is CEDARVILLE. The address state for this practitioner is MA. The address postalCode for this practitioner is 02360-6903. The address country for this practitioner is US. The gender for this practitioner is female.", "name": "Practitioner"}
# ---------------------------------------------------------------
# Encounter
# ---------------------------------------------------------------
# The type of information in this entry is encounter. The status for this encounter is finished. The class for this encounter is AMB. The type of this encounter is Well child visit (procedure). This encounter was period start on 07/23/2019 at 00:19:26. This encounter was period end on 07/23/2019 at 00:49:26.
# {"resource_type": "Encounter", "id": "6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "status": "finished", "class_system": "http://terminology.hl7.org/CodeSystem/v3-ActCode", "class_code": "AMB", "type_0_coding_0_system": "http://snomed.info/sct", "type_0_coding_0_code": "410620009", "type_0_coding_0_display": "Well child visit (procedure)", "type_0_text": "Well child visit (procedure)", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "subject_display": "Cassy835 Kohler843", "participant_0_individual_reference": "urn:uuid:0000016d-3a85-4cca-0000-000000016be8", "participant_0_individual_display": "Dr. Robena997 Schamberger479", "period_start": "2019-07-23T00:19:26-04:00", "period_end": "2019-07-23T00:49:26-04:00", "service_provider_reference": "urn:uuid:a0a14713-50c4-3818-b0cb-8c2047f1458c", "service_provider_display": "BAY STATE PHYSICAL THERAPY OF RANDOLPH PC", "text": "The type of information in this entry is encounter. The status for this encounter is finished. The class for this encounter is AMB. The type of this encounter is Well child visit (procedure). This encounter was period start on 07/23/2019 at 00:19:26. This encounter was period end on 07/23/2019 at 00:49:26.", "name": "Encounter"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Height. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 49.68301530530686 cm.
# {"resource_type": "Observation", "id": "da1fad75-98e4-4b4e-9050-6f332f9a9f28", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "8302-2", "code_coding_0_display": "Body Height", "code_text": "Body Height", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 49.68301530530686, "value_quantity_unit": "cm", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "cm", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Height. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 49.68301530530686 cm.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Pain severity - 0-10 verbal numeric rating [Score] - Reported. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 0.87215339533559 {score}.
# {"resource_type": "Observation", "id": "08973552-b6b9-4849-bf1a-e0855469a34b", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "72514-3", "code_coding_0_display": "Pain severity - 0-10 verbal numeric rating [Score] - Reported", "code_text": "Pain severity - 0-10 verbal numeric rating [Score] - Reported", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 0.87215339533559, "value_quantity_unit": "{score}", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "{score}", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Pain severity - 0-10 verbal numeric rating [Score] - Reported. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 0.87215339533559 {score}.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Weight. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 4.386792067875933 kg.
# {"resource_type": "Observation", "id": "61ebcb42-f4f6-4da8-b761-623ad6d0e212", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "29463-7", "code_coding_0_display": "Body Weight", "code_text": "Body Weight", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 4.386792067875933, "value_quantity_unit": "kg", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "kg", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Weight. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 4.386792067875933 kg.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Weight-for-length Per age and sex. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 98.95022469502467 %.
# {"resource_type": "Observation", "id": "e7125306-956d-44e8-9224-513640819696", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "77606-2", "code_coding_0_display": "Weight-for-length Per age and sex", "code_text": "Weight-for-length Per age and sex", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 98.95022469502467, "value_quantity_unit": "%", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "%", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Weight-for-length Per age and sex. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 98.95022469502467 %.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 72.67505083987548 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 112.58007206680915 mm[Hg].
# {"resource_type": "Observation", "id": "5d0d74d0-d1e9-408c-8ea8-9ddc0abbaa8a", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "55284-4", "code_coding_0_display": "Blood Pressure", "code_text": "Blood Pressure", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "component_0_code_coding_0_system": "http://loinc.org", "component_0_code_coding_0_code": "8462-4", "component_0_code_coding_0_display": "Diastolic Blood Pressure", "component_0_code_text": "Diastolic Blood Pressure", "component_0_value_quantity_value": 72.67505083987548, "component_0_value_quantity_unit": "mm[Hg]", "component_0_value_quantity_system": "http://unitsofmeasure.org", "component_0_value_quantity_code": "mm[Hg]", "component_1_code_coding_0_system": "http://loinc.org", "component_1_code_coding_0_code": "8480-6", "component_1_code_coding_0_display": "Systolic Blood Pressure", "component_1_code_text": "Systolic Blood Pressure", "component_1_value_quantity_value": 112.58007206680915, "component_1_value_quantity_unit": "mm[Hg]", "component_1_value_quantity_system": "http://unitsofmeasure.org", "component_1_value_quantity_code": "mm[Hg]", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 72.67505083987548 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 112.58007206680915 mm[Hg].", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Leukocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 5.70682213630657 10*3/uL.
# {"resource_type": "Observation", "id": "b20529e7-a2ed-4ad6-b160-5c44a25d9cb4", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "6690-2", "code_coding_0_display": "Leukocytes [#/volume] in Blood by Automated count", "code_text": "Leukocytes [#/volume] in Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 5.70682213630657, "value_quantity_unit": "10*3/uL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "10*3/uL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Leukocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 5.70682213630657 10*3/uL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 3.989686953763341 10*6/uL.
# {"resource_type": "Observation", "id": "8e72933f-58a7-4689-8f8d-cf7c590d9725", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "789-8", "code_coding_0_display": "Erythrocytes [#/volume] in Blood by Automated count", "code_text": "Erythrocytes [#/volume] in Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 3.989686953763341, "value_quantity_unit": "10*6/uL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "10*6/uL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 3.989686953763341 10*6/uL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hemoglobin [Mass/volume] in Blood. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 12.99857902400672 g/dL.
# {"resource_type": "Observation", "id": "1ea9f384-23af-4665-9f59-07d594cfb7b1", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "718-7", "code_coding_0_display": "Hemoglobin [Mass/volume] in Blood", "code_text": "Hemoglobin [Mass/volume] in Blood", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 12.99857902400672, "value_quantity_unit": "g/dL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "g/dL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hemoglobin [Mass/volume] in Blood. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 12.99857902400672 g/dL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hematocrit [Volume Fraction] of Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 36.6438714911998 %.
# {"resource_type": "Observation", "id": "0f7e439b-4af7-4a1d-a75b-4592ea3d6175", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "4544-3", "code_coding_0_display": "Hematocrit [Volume Fraction] of Blood by Automated count", "code_text": "Hematocrit [Volume Fraction] of Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 36.6438714911998, "value_quantity_unit": "%", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "%", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hematocrit [Volume Fraction] of Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 36.6438714911998 %.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCV [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 86.77031118764091 fL.
# {"resource_type": "Observation", "id": "92193bce-34e1-4365-b5d3-17775b7f3fc7", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "787-2", "code_coding_0_display": "MCV [Entitic volume] by Automated count", "code_text": "MCV [Entitic volume] by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 86.77031118764091, "value_quantity_unit": "fL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "fL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCV [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 86.77031118764091 fL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCH [Entitic mass] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 28.028486460769575 pg.
# {"resource_type": "Observation", "id": "ec3b5a77-750b-4aba-bec5-dbf19e4d5c9e", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "785-6", "code_coding_0_display": "MCH [Entitic mass] by Automated count", "code_text": "MCH [Entitic mass] by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 28.028486460769575, "value_quantity_unit": "pg", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "pg", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCH [Entitic mass] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 28.028486460769575 pg.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCHC [Mass/volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 34.753638718757024 g/dL.
# {"resource_type": "Observation", "id": "716509ff-b750-4696-9406-a380b95385b7", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "786-4", "code_coding_0_display": "MCHC [Mass/volume] by Automated count", "code_text": "MCHC [Mass/volume] by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 34.753638718757024, "value_quantity_unit": "g/dL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "g/dL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCHC [Mass/volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 34.753638718757024 g/dL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocyte distribution width [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 45.54777092071412 fL.
# {"resource_type": "Observation", "id": "3e8d4b7b-ebbc-4e11-913d-e151b6bc5fe8", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "21000-5", "code_coding_0_display": "Erythrocyte distribution width [Entitic volume] by Automated count", "code_text": "Erythrocyte distribution width [Entitic volume] by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 45.54777092071412, "value_quantity_unit": "fL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "fL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocyte distribution width [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 45.54777092071412 fL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelets [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 422.9270774385219 10*3/uL.
# {"resource_type": "Observation", "id": "a3668227-1910-483c-a0a2-5e0d61c8e819", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "777-3", "code_coding_0_display": "Platelets [#/volume] in Blood by Automated count", "code_text": "Platelets [#/volume] in Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 422.9270774385219, "value_quantity_unit": "10*3/uL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "10*3/uL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelets [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 422.9270774385219 10*3/uL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet distribution width [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 463.65102405584287 fL.
# {"resource_type": "Observation", "id": "99ba872a-516d-4d12-abdf-e75696f3dd34", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "32207-3", "code_coding_0_display": "Platelet distribution width [Entitic volume] in Blood by Automated count", "code_text": "Platelet distribution width [Entitic volume] in Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 463.65102405584287, "value_quantity_unit": "fL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "fL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet distribution width [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 463.65102405584287 fL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet mean volume [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 10.025951302034839 fL.
# {"resource_type": "Observation", "id": "f2457979-599d-48c5-8d13-ea3cfaa59824", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "laboratory", "category_0_coding_0_display": "laboratory", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "32623-1", "code_coding_0_display": "Platelet mean volume [Entitic volume] in Blood by Automated count", "code_text": "Platelet mean volume [Entitic volume] in Blood by Automated count", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_quantity_value": 10.025951302034839, "value_quantity_unit": "fL", "value_quantity_system": "http://unitsofmeasure.org", "value_quantity_code": "fL", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet mean volume [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 10.025951302034839 fL.", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.
# {"resource_type": "Observation", "id": "746f4f78-7de2-4101-bc44-c65952dcbf69", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "survey", "category_0_coding_0_display": "survey", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "72166-2", "code_coding_0_display": "Tobacco smoking status NHIS", "code_text": "Tobacco smoking status NHIS", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "effective_date_time": "2019-07-23T00:19:26-04:00", "issued": "2019-07-23T00:19:26.134-04:00", "value_codeable_concept_coding_0_system": "http://snomed.info/sct", "value_codeable_concept_coding_0_code": "266919005", "value_codeable_concept_coding_0_display": "Never smoker", "value_codeable_concept_text": "Never smoker", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.", "name": "Observation"}
# ---------------------------------------------------------------
# Procedure
# ---------------------------------------------------------------
# The type of information in this entry is procedure. The status for this procedure is completed. The code for this procedure is Medication Reconciliation (procedure). This procedure was performed period start on 07/23/2019 at 00:19:26. This procedure was performed period end on 07/23/2019 at 00:34:26.
# {"resource_type": "Procedure", "id": "d889fcd9-64de-4936-ae8b-c45c234b147c", "status": "completed", "code_coding_0_system": "http://snomed.info/sct", "code_coding_0_code": "430193006", "code_coding_0_display": "Medication Reconciliation (procedure)", "code_text": "Medication Reconciliation (procedure)", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "performed_period_start": "2019-07-23T00:19:26-04:00", "performed_period_end": "2019-07-23T00:34:26-04:00", "text": "The type of information in this entry is procedure. The status for this procedure is completed. The code for this procedure is Medication Reconciliation (procedure). This procedure was performed period start on 07/23/2019 at 00:19:26. This procedure was performed period end on 07/23/2019 at 00:34:26.", "name": "Procedure"}
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 07/23/2019 at 00:19:26. The primary source for this immunization is True.
# {"resource_type": "Immunization", "id": "d5cb19d1-5dd2-4807-8523-aa713b765ca4", "status": "completed", "vaccine_code_coding_0_system": "http://hl7.org/fhir/sid/cvx", "vaccine_code_coding_0_code": "08", "vaccine_code_coding_0_display": "Hep B, adolescent or pediatric", "vaccine_code_text": "Hep B, adolescent or pediatric", "patient_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:6d6c07f8-0521-48f6-860b-953a6cd0aa2c", "occurrence_date_time": "2019-07-23T00:19:26-04:00", "primary_source": true, "text": "The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 07/23/2019 at 00:19:26. The primary source for this immunization is True.", "name": "Immunization"}
# ---------------------------------------------------------------
# DiagnosticReport
# ---------------------------------------------------------------
#
# ...
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 77.98572493460571 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 109.77321481812324 mm[Hg].
# {"resource_type": "Observation", "id": "139a5042-3d4c-4a67-ae68-c59e81cdbfd2", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "vital-signs", "category_0_coding_0_display": "vital-signs", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "55284-4", "code_coding_0_display": "Blood Pressure", "code_text": "Blood Pressure", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:be779465-3532-446c-9003-40a509b6a038", "effective_date_time": "2019-08-27T00:19:26-04:00", "issued": "2019-08-27T00:19:26.134-04:00", "component_0_code_coding_0_system": "http://loinc.org", "component_0_code_coding_0_code": "8462-4", "component_0_code_coding_0_display": "Diastolic Blood Pressure", "component_0_code_text": "Diastolic Blood Pressure", "component_0_value_quantity_value": 77.98572493460571, "component_0_value_quantity_unit": "mm[Hg]", "component_0_value_quantity_system": "http://unitsofmeasure.org", "component_0_value_quantity_code": "mm[Hg]", "component_1_code_coding_0_system": "http://loinc.org", "component_1_code_coding_0_code": "8480-6", "component_1_code_coding_0_display": "Systolic Blood Pressure", "component_1_code_text": "Systolic Blood Pressure", "component_1_value_quantity_value": 109.77321481812324, "component_1_value_quantity_unit": "mm[Hg]", "component_1_value_quantity_system": "http://unitsofmeasure.org", "component_1_value_quantity_code": "mm[Hg]", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 77.98572493460571 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 109.77321481812324 mm[Hg].", "name": "Observation"}
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.
# {"resource_type": "Observation", "id": "ca2acaf7-312a-4faf-a8ad-bc139e59ec49", "status": "final", "category_0_coding_0_system": "http://terminology.hl7.org/CodeSystem/observation-category", "category_0_coding_0_code": "survey", "category_0_coding_0_display": "survey", "code_coding_0_system": "http://loinc.org", "code_coding_0_code": "72166-2", "code_coding_0_display": "Tobacco smoking status NHIS", "code_text": "Tobacco smoking status NHIS", "subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:be779465-3532-446c-9003-40a509b6a038", "effective_date_time": "2019-08-27T00:19:26-04:00", "issued": "2019-08-27T00:19:26.134-04:00", "value_codeable_concept_coding_0_system": "http://snomed.info/sct", "value_codeable_concept_coding_0_code": "266919005", "value_codeable_concept_coding_0_display": "Never smoker", "value_codeable_concept_text": "Never smoker", "text": "The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.", "name": "Observation"}
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 08/27/2019 at 00:19:26. The primary source for this immunization is True.
# {"resource_type": "Immunization", "id": "30addaa5-6e72-40a2-88f2-8c31cb651f0e", "status": "completed", "vaccine_code_coding_0_system": "http://hl7.org/fhir/sid/cvx", "vaccine_code_coding_0_code": "08", "vaccine_code_coding_0_display": "Hep B, adolescent or pediatric", "vaccine_code_text": "Hep B, adolescent or pediatric", "patient_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "encounter_reference": "urn:uuid:be779465-3532-446c-9003-40a509b6a038", "occurrence_date_time": "2019-08-27T00:19:26-04:00", "primary_source": true, "text": "The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 08/27/2019 at 00:19:26. The primary source for this immunization is True.", "name": "Immunization"}
# ---------------------------------------------------------------
# Claim
# ---------------------------------------------------------------
# The type of information in this entry is claim. The status for this claim is active. The type of this claim is institutional. The use for this claim is claim. This claim was billable period start on 08/27/2019 at 00:19:26. This claim was billable period end on 08/27/2019 at 00:34:26. This claim was created on 08/27/2019 at 00:34:26. The priority for this claim is normal. The supporting info sequence for this claim is 1. The supporting info category of this claim is info. The insurance for this claim is Anthem. The 2nd item for this claim is Well child visit (procedure). The 3rd item for this claim is Well child visit (procedure). The total for this claim is 129.16 USD.
# {"resource_type": "Claim", "id": "fc33c341-8443-4320-be48-97d14005ac36", "status": "active", "type_coding_0_system": "http://terminology.hl7.org/CodeSystem/claim-type", "type_coding_0_code": "institutional", "use": "claim", "patient_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "patient_display": "Cassy835 Kohler843", "billable_period_start": "2019-08-27T00:19:26-04:00", "billable_period_end": "2019-08-27T00:34:26-04:00", "created": "2019-08-27T00:34:26-04:00", "provider_reference": "urn:uuid:a0a14713-50c4-3818-b0cb-8c2047f1458c", "provider_display": "BAY STATE PHYSICAL THERAPY OF RANDOLPH PC", "priority_coding_0_system": "http://terminology.hl7.org/CodeSystem/processpriority", "priority_coding_0_code": "normal", "supporting_info_0_sequence": 1, "supporting_info_0_category_coding_0_system": "http://terminology.hl7.org/CodeSystem/claiminformationcategory", "supporting_info_0_category_coding_0_code": "info", "supporting_info_0_value_reference_reference": "urn:uuid:30addaa5-6e72-40a2-88f2-8c31cb651f0e", "insurance_0_sequence": 1, "insurance_0_focal": true, "insurance_0_coverage_display": "Anthem", "item_0_sequence": 1, "item_0_product_or_service_coding_0_system": "http://snomed.info/sct", "item_0_product_or_service_coding_0_code": "410620009", "item_0_product_or_service_coding_0_display": "Well child visit (procedure)", "item_0_product_or_service_text": "Well child visit (procedure)", "item_0_encounter_0_reference": "urn:uuid:be779465-3532-446c-9003-40a509b6a038", "item_1_sequence": 2, "item_1_information_sequence_0": 1, "item_1_product_or_service_coding_0_system": "http://hl7.org/fhir/sid/cvx", "item_1_product_or_service_coding_0_code": "08", "item_1_product_or_service_coding_0_display": "Hep B, adolescent or pediatric", "item_1_product_or_service_text": "Hep B, adolescent or pediatric", "item_1_net_value": 140.52, "item_1_net_currency": "USD", "total_value": 129.16, "total_currency": "USD", "text": "The type of information in this entry is claim. The status for this claim is active. The type of this claim is institutional. The use for this claim is claim. This claim was billable period start on 08/27/2019 at 00:19:26. This claim was billable period end on 08/27/2019 at 00:34:26. This claim was created on 08/27/2019 at 00:34:26. The priority for this claim is normal. The supporting info sequence for this claim is 1. The supporting info category of this claim is info. The insurance for this claim is Anthem. The 2nd item for this claim is Well child visit (procedure). The 3rd item for this claim is Well child visit (procedure). The total for this claim is 129.16 USD.", "name": "Claim"}
# ---------------------------------------------------------------
# ExplanationOfBenefit
# ---------------------------------------------------------------
# The type of information in this entry is explanation of benefit. The type of information in this 1st subexplanation of benefit is service request. The status for this service request is completed. The intent for this service request is order. The type of information in this 2nd subexplanation of benefit is coverage. The status for this coverage is active. The type of this coverage is {'text': 'Anthem'}. The payor display for this coverage is Anthem. The status for this explanation of benefit is active. The type of this explanation of benefit is institutional. The use for this explanation of benefit is claim. This explanation of benefit was billable period start on 08/27/2019 at 00:34:26. This explanation of benefit was billable period end on 08/27/2020 at 00:34:26. This explanation of benefit was created on 08/27/2019 at 00:34:26. The insurer display for this explanation of benefit is Anthem. The outcome for this explanation of benefit is complete. The care team sequence for this explanation of benefit is 1. The care team role for this explanation of benefit is Primary Care Practitioner. The insurance for this explanation of benefit is Anthem. The 2nd item for this explanation of benefit is Well child visit (procedure). The 3rd item for this explanation of benefit is Well child visit (procedure). The total category of this explanation of benefit is Submitted Amount. The total amount for this explanation of benefit is 129.16 USD. The payment amount for this explanation of benefit is 112.41600000000001 USD.
# {"resource_type": "ExplanationOfBenefit", "id": "e010636f-237e-4756-897b-b8b64dfc991a", "contained_0_resource_type": "ServiceRequest", "contained_0_id": "referral", "contained_0_status": "completed", "contained_0_intent": "order", "contained_0_subject_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "contained_0_requester_reference": "urn:uuid:0000016d-3a85-4cca-0000-000000016be8", "contained_0_performer_0_reference": "urn:uuid:0000016d-3a85-4cca-0000-000000016be8", "contained_1_resource_type": "Coverage", "contained_1_id": "coverage", "contained_1_status": "active", "contained_1_type_text": "Anthem", "contained_1_beneficiary_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "contained_1_payor_0_display": "Anthem", "identifier_0_system": "https://bluebutton.cms.gov/resources/variables/clm_id", "identifier_0_value": "fc33c341-8443-4320-be48-97d14005ac36", "identifier_1_system": "https://bluebutton.cms.gov/resources/identifier/claim-group", "identifier_1_value": "99999999999", "status": "active", "type_coding_0_system": "http://terminology.hl7.org/CodeSystem/claim-type", "type_coding_0_code": "institutional", "use": "claim", "patient_reference": "urn:uuid:a0917f1f-b1b9-4656-a48e-851bf15fede3", "billable_period_start": "2019-08-27T00:34:26-04:00", "billable_period_end": "2020-08-27T00:34:26-04:00", "created": "2019-08-27T00:34:26-04:00", "insurer_display": "Anthem", "provider_reference": "urn:uuid:0000016d-3a85-4cca-0000-000000016be8", "referral_reference": "#referral", "claim_reference": "urn:uuid:fc33c341-8443-4320-be48-97d14005ac36", "outcome": "complete", "care_team_0_sequence": 1, "care_team_0_provider_reference": "urn:uuid:0000016d-3a85-4cca-0000-000000016be8", "care_team_0_role_coding_0_system": "http://terminology.hl7.org/CodeSystem/claimcareteamrole", "care_team_0_role_coding_0_code": "primary", "care_team_0_role_coding_0_display": "Primary Care Practitioner", "insurance_0_focal": true, "insurance_0_coverage_reference": "#coverage", "insurance_0_coverage_display": "Anthem", "item_0_sequence": 1, "item_0_category_coding_0_system": "https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd", "item_0_category_coding_0_code": "1", "item_0_category_coding_0_display": "Medical care", "item_0_product_or_service_coding_0_system": "http://snomed.info/sct", "item_0_product_or_service_coding_0_code": "410620009", "item_0_product_or_service_coding_0_display": "Well child visit (procedure)", "item_0_product_or_service_text": "Well child visit (procedure)", "item_0_serviced_period_start": "2019-08-27T00:19:26-04:00", "item_0_serviced_period_end": "2019-08-27T00:34:26-04:00", "item_0_location_codeable_concept_coding_0_system": "http://terminology.hl7.org/CodeSystem/ex-serviceplace", "item_0_location_codeable_concept_coding_0_code": "19", "item_0_location_codeable_concept_coding_0_display": "Off Campus-Outpatient Hospital", "item_0_encounter_0_reference": "urn:uuid:be779465-3532-446c-9003-40a509b6a038", "item_1_sequence": 2, "item_1_information_sequence_0": 1, "item_1_category_coding_0_system": "https://bluebutton.cms.gov/resources/variables/line_cms_type_srvc_cd", "item_1_category_coding_0_code": "1", "item_1_category_coding_0_display": "Medical care", "item_1_product_or_service_coding_0_system": "http://hl7.org/fhir/sid/cvx", "item_1_product_or_service_coding_0_code": "08", "item_1_product_or_service_coding_0_display": "Hep B, adolescent or pediatric", "item_1_product_or_service_text": "Hep B, adolescent or pediatric", "item_1_serviced_period_start": "2019-08-27T00:19:26-04:00", "item_1_serviced_period_end": "2019-08-27T00:34:26-04:00", "item_1_location_codeable_concept_coding_0_system": "http://terminology.hl7.org/CodeSystem/ex-serviceplace", "item_1_location_codeable_concept_coding_0_code": "19", "item_1_location_codeable_concept_coding_0_display": "Off Campus-Outpatient Hospital", "item_1_net_value": 140.52, "item_1_net_currency": "USD", "item_1_adjudication_0_category_coding_0_system": "https://bl ...

# %% [markdown]
# ## Understand the fields and references

# %%
## Lets understand all the references
with open('fhir_resources/Cassy835_Kohler843_01b6ca2a-b591-4560-9014-c37e1565f0cd.json') as raw:
    bundle = json.load(raw)
    for entry in bundle['entry']:
        resource_type = entry['resource']['resourceType']
        if resource_type != 'Provenance':
            print("---------------------------------------------------------------")
            print(resource_type)
            print("---------------------------------------------------------------")
            flattened_resource = resource_to_string(entry['resource']) # This is a dictionary
            keys = [k for k, v in flattened_resource.items()]  # Gets all the keys
            keys = [k for k, v in flattened_resource.items() if "reference" in k]  # Only gets reference fields
            print(keys)  # Prints all the keys
            print(flattened_resource['text'])
            # print(json.dumps(bundle))
# Out:
# ---------------------------------------------------------------
# Patient
# ---------------------------------------------------------------
# []
# The type of information in this entry is patient. The name use for this patient is official. The name family for this patient is Kohler843. The name given for this patient is Cassy835. The telecom system for this patient is phone. The telecom value for this patient is 555-292-5994. The telecom use for this patient is home. The gender for this patient is female. The birth date for this patient is 2019-07-23. The address line for this patient is 949 Crist Burg Unit 59. The address city for this patient is Plymouth. The address state for this patient is Massachusetts. The address postalCode for this patient is 02360. The address country for this patient is US. The marital status for this patient is Never Married. The multiple birth boolean for this patient is False. The communication language for this patient is English.
# ---------------------------------------------------------------
# Organization
# ---------------------------------------------------------------
# []
# The type of information in this entry is organization. The active for this organization is True. The type of this organization is Healthcare Provider. The name for this organization is BAY STATE PHYSICAL THERAPY OF RANDOLPH PC. The telecom system for this organization is phone. The telecom value for this organization is 508-833-5180. The address line for this organization is 7 HERRING POND RD. The address city for this organization is CEDARVILLE. The address state for this organization is MA. The address postalCode for this organization is 02360-6903. The address country for this organization is US.
# ---------------------------------------------------------------
# Practitioner
# ---------------------------------------------------------------
# []
# The type of information in this entry is practitioner. The active for this practitioner is True. The name family for this practitioner is Schamberger479. The name given for this practitioner is Robena997. The name prefix for this practitioner is Dr.. The telecom system for this practitioner is email. The telecom value for this practitioner is Robena997.Schamberger479@example.com. The telecom use for this practitioner is work. The address line for this practitioner is 7 HERRING POND RD. The address city for this practitioner is CEDARVILLE. The address state for this practitioner is MA. The address postalCode for this practitioner is 02360-6903. The address country for this practitioner is US. The gender for this practitioner is female.
# ---------------------------------------------------------------
# Encounter
# ---------------------------------------------------------------
# ['subject_reference', 'participant_0_individual_reference', 'service_provider_reference']
# The type of information in this entry is encounter. The status for this encounter is finished. The class for this encounter is AMB. The type of this encounter is Well child visit (procedure). This encounter was period start on 07/23/2019 at 00:19:26. This encounter was period end on 07/23/2019 at 00:49:26.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Height. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 49.68301530530686 cm.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Pain severity - 0-10 verbal numeric rating [Score] - Reported. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 0.87215339533559 {score}.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Weight. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 4.386792067875933 kg.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Weight-for-length Per age and sex. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 98.95022469502467 %.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 72.67505083987548 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 112.58007206680915 mm[Hg].
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Leukocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 5.70682213630657 10*3/uL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocytes [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 3.989686953763341 10*6/uL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hemoglobin [Mass/volume] in Blood. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 12.99857902400672 g/dL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Hematocrit [Volume Fraction] of Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 36.6438714911998 %.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCV [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 86.77031118764091 fL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCH [Entitic mass] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 28.028486460769575 pg.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is MCHC [Mass/volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 34.753638718757024 g/dL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Erythrocyte distribution width [Entitic volume] by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 45.54777092071412 fL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelets [#/volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 422.9270774385219 10*3/uL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet distribution width [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 463.65102405584287 fL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is laboratory. The code for this observation is Platelet mean volume [Entitic volume] in Blood by Automated count. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value quantity for this observation is 10.025951302034839 fL.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.
# ---------------------------------------------------------------
# Procedure
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is procedure. The status for this procedure is completed. The code for this procedure is Medication Reconciliation (procedure). This procedure was performed period start on 07/23/2019 at 00:19:26. This procedure was performed period end on 07/23/2019 at 00:34:26.
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# ['patient_reference', 'encounter_reference']
# The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 07/23/2019 at 00:19:26. The primary source for this immunization is True.
# ---------------------------------------------------------------
# DiagnosticReport
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference', 'result_0_reference', 'result_1_reference', 'result_2_reference', 'result_3_reference', 'result_4_reference', 'result_5_reference', 'result_6_reference', 'result_7_reference', 'result_8_reference', 'result_9_reference', 'result_10_reference']
#
# ---------------------------------------------------------------
# Claim
# ---------------------------------------------------------------
# ['patient_reference', 'provider_reference', 'supporting_info_0_value_reference_reference', 'procedure_0_procedure_reference_reference', 'item_0_encounter_0_reference']
# The type of information in this entry is claim. The status for this claim is active. The type of this claim is institutional. The use for this claim is claim. This claim was billable period start on 07/23/2019 at 00:19:26. This claim was billable period end on 07/23/2019 at 00:49:26. This claim was created on 07/23/2019 at 00:49:26. The priority for this claim is normal. The supporting info sequence for this claim is 1. The supporting info category of this claim is info. The procedure sequence for this claim is 1. The insurance for this claim is Anthem. The 2nd item for this claim is Well child visit (procedure). The 3rd item for this claim is Well child visit (procedure). The 4th item for this claim is Well child visit (procedure). The total for this claim is 129.16 USD.
# ---------------------------------------------------------------
# ExplanationOfBenefit
# ---------------------------------------------------------------
# ['contained_0_subject_reference', 'contained_0_requester_reference', 'contained_0_performer_0_reference', 'contained_1_beneficiary_reference', 'patient_reference', 'provider_reference', 'referral_reference', 'claim_reference', 'care_team_0_provider_reference', 'insurance_0_coverage_reference', 'item_0_encounter_0_reference']
# The type of information in this entry is explanation of benefit. The type of information in this 1st subexplanation of benefit is service request. The status for this service request is completed. The intent for this service request is order. The type of information in this 2nd subexplanation of benefit is coverage. The status for this coverage is active. The type of this coverage is {'text': 'Anthem'}. The payor display for this coverage is Anthem. The status for this explanation of benefit is active. The type of this explanation of benefit is institutional. The use for this explanation of benefit is claim. This explanation of benefit was billable period start on 07/23/2019 at 00:49:26. This explanation of benefit was billable period end on 07/23/2020 at 00:49:26. This explanation of benefit was created on 07/23/2019 at 00:49:26. The insurer display for this explanation of benefit is Anthem. The outcome for this explanation of benefit is complete. The care team sequence for this explanation of benefit is 1. The care team role for this explanation of benefit is Primary Care Practitioner. The insurance for this explanation of benefit is Anthem. The 2nd item for this explanation of benefit is Well child visit (procedure). The 3rd item for this explanation of benefit is Well child visit (procedure). The 4th item for this explanation of benefit is Well child visit (procedure). The total category of this explanation of benefit is Submitted Amount. The total amount for this explanation of benefit is 129.16 USD. The payment amount for this explanation of benefit is 737.2960000000002 USD.
# ---------------------------------------------------------------
# Encounter
# ---------------------------------------------------------------
# ['subject_reference', 'participant_0_individual_reference', 'service_provider_reference']
# The type of information in this entry is encounter. The status for this encounter is finished. The class for this encounter is AMB. The type of this encounter is Well child visit (procedure). This encounter was period start on 08/27/2019 at 00:19:26. This encounter was period end on 08/27/2019 at 00:34:26.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Height. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value quantity for this observation is 53.26791704148272 cm.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Pain severity - 0-10 verbal numeric rating [Score] - Reported. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value quantity for this observation is 3.4217797869994597 {score}.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Body Weight. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value quantity for this observation is 5.230470676785828 kg.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Weight-for-length Per age and sex. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value quantity for this observation is 98.62875464653199 %.
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st component's value quantity for this observation is 77.98572493460571 mm[Hg]. The 2nd component's code for this observation is Systolic Blood Pressure. The 2nd component's value quantity for this observation is 109.77321481812324 mm[Hg].
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ['subject_reference', 'encounter_reference']
# The type of information in this entry is observation. The status for this observation is final. The category of this observation is survey. The code for this observation is Tobacco smoking status NHIS. This observation was effective date time on 08/27/2019 at 00:19:26. This observation was issued on 08/27/2019 at 00:19:26. The value codeable concept for this observation is Never smoker.
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# ['patient_reference', 'encounter_reference']
# The type of information in this entry is immunization. The status for this immunization is completed. The vaccine code for this immunization is Hep B, adolescent or pediatric. This immunization was occurrence date time on 08/27/2019 at 00:19:26. The primary source for this immunization is True.
# ---------------------------------------------------------------
# Claim
# ---------------------------------------------------------------
# ['patient_reference', 'provider_reference', 'supporting_info_0_value_reference_reference', 'item_0_encounter_0_reference']
# The type of information in this entry is claim. The status for this claim is active. The type of this claim is institutional. The use for this claim is claim. This claim was billable period start on 08/27/2019 at 00:19:26. This claim was billable period end on 08/27/2019 at 00:34:26. This claim was created on 08/27/2019 at 00:34:26. The priority for this claim is normal. The supporting info sequence for this claim is 1. The supporting info category of this claim is info. The insurance for this claim is Anthem. The 2nd item for this claim is Well child visit (procedure). The 3rd item for this claim is Well child visit (procedure). The total for this claim is 129.16 USD.
# ---------------------------------------------------------------
# ExplanationOfBenefit
# ---------------------------------------------------------------
# ['contained_0_subject_reference', 'contained_0_requester_reference', 'contained_0_performer_0_reference', 'contained_1_beneficiary_reference', 'patient_reference', 'provider_reference', 'referral_reference', 'claim_reference', 'care_team_0_provider_reference', 'insurance_0_coverage_reference', 'item_0_encounter_0_reference']
# The type of information in this entry is explanation of benefit. The type of information in this 1st subexplanation of benefit is service request. The status for this service request is completed. The intent for this service request is order. The type of information in this 2nd subexplanation of benefit is coverage. The status for this coverage is active. The type of this coverage is {'text': 'Anthem'}. The payor display for this coverage is Anthem. The status for this explanation of benefit is active. The type of this explanation of benefit is institutional. The use for this explanation of benefit is claim. This explanation of benefit was billable period start on 08/27/2019 at 00:34:26. This explanation of benefit was billable period end on 08/27/2020 at 00:34:26. This explanation of benefit was created on 08/27/2019 at 00:34:26. The insurer display for this explanation of benefit is Anthem. The outcome for this explanation of benefit is complete. The care team sequence for this explanation of benefit is 1. The care team role for this explanation of benefit is Primary Care Practitioner. The insurance for this explanation of benefit is Anthem. The 2nd item for this explanation of benefit is Well child visit (procedure). The 3rd item for this explanation of benefit is Well child visit (procedure). The total category of this explanation of benefit is Submitted Amount. The total amount for this explanation of benefit is 129.16 USD. The payment amount for this explanation of benefit is 112.41600000000001 USD.

# %% [markdown]
# ## Prepare embedding model
#
# Example used open AI model we want a different one

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %% [markdown]
# Testing embeddings

# %%
embeddings = embed_model.get_text_embedding("The type of information in this entry is observation. The status for this observation is final. The category of this observation is vital-signs. The code for this observation is Blood Pressure. This observation was effective date time on 07/23/2019 at 00:19:26. This observation was issued on 07/23/2019 at 00:19:26. This observation contains 2 components. The 1st component's code for this observation is Diastolic Blood Pressure. The 1st com")
print(len(embeddings))
embedding_dim = len(embeddings)

print(embeddings[:5])
# Out:
# 384
# [-0.039267104119062424, 0.04040497913956642, -0.018152697011828423, -0.020609106868505478, 0.06916255503892899]

# %% [markdown]
# ## Load data in Milvus
# Create connection and collection - using the local in library version

# %%
from pymilvus import MilvusClient, DataType

milvus_client = MilvusClient(uri="./milvus_fhir.db")

# %%
collection_name = "my_fhir_collection"

# %% [markdown]
# As for the argument of MilvusClient:
#
# * Setting the uri as a local file, e.g../milvus.db, is the most convenient method, as it automatically utilizes Milvus Lite to store all data in this file.
# * If you have large scale of data, you can set up a more performant Milvus server on docker or kubernetes. In this setup, please use the server uri, e.g.http://localhost:19530, as your uri.
# * If you want to use Zilliz Cloud, the fully managed cloud service for Milvus, adjust the uri and token, which correspond to the Public Endpoint and Api key in Zilliz Cloud.

# %%
# if the collection exists create a new one
if milvus_client.has_collection(collection_name):
    milvus_client.drop_collection(collection_name)

# %% [markdown]
# Create a new collection with specified parameters.
#
# If we don't specify any field information, Milvus will automatically create a default id field for primary key, and a vector field to store the vector data. A reserved JSON field is used to store non-schema-defined fields and their values.
#
# Filtering is also possible: https://milvus.io/docs/filtered-search.md

# %%
schema = milvus_client.create_schema(
    auto_id = False,
    enable_dynamic_fields=True
)

schema.add_field(field_name="resource", datatype=DataType.JSON)
schema.add_field(field_name="id", datatype=DataType.VARCHAR, max_length=64, is_primary=True)
schema.add_field(field_name="embedding", datatype=DataType.FLOAT_VECTOR, dim=embedding_dim)

index_params = milvus_client.prepare_index_params()

# Index for embedding to speed things up
index_params.add_index(
    field_name="embedding",
    index_type="AUTOINDEX",
    metric_type="COSINE"
)
    

milvus_client.create_collection(
    collection_name=collection_name,
    schema=schema,
    index_params=index_params
    #metric_type="IP",  # Inner product distance
    #consistency_level="Strong",  # Strong consistency level
)

# %% [markdown]
# ## Insert data
#
# Iterate through the text lines, create embeddings, and then insert the data into Milvus.
#
# Here is a new field text, which is a non-defined field in the collection schema. It will be automatically added to the reserved JSON dynamic field, which can be treated as a normal field at a high level.

# %%
from tqdm import tqdm

# %%
with open('fhir_resources/Cassy835_Kohler843_01b6ca2a-b591-4560-9014-c37e1565f0cd.json') as raw:
    bundle = json.load(raw)
    for entry in bundle['entry']:
        resource_type = entry['resource']['resourceType']
        if resource_type != 'Provenance':
            print("---------------------------------------------------------------")
            print(resource_type)
            print("---------------------------------------------------------------")
            flattened_resource = resource_to_string(entry['resource']) # This is a dictionary
            #keys = [k for k, v in flattened_resource.items()]  # Gets all the keys
            #keys = [k for k, v in flattened_resource.items() if "reference" in k]  # Only gets reference fields
            #print(keys)  # Prints all the keys
            #print(flattened_resource['text'])
            # print(json.dumps(flattened_resource))
            #data = []  # Surely bulk insert would be better
            data = {"id": flattened_resource['id'], "embedding": embed_model.get_text_embedding(flattened_resource['text']), "resource": flattened_resource}
            milvus_client.insert(collection_name=collection_name, data=data)
# Out:
# ---------------------------------------------------------------
# Patient
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Organization
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Practitioner
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Encounter
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Procedure
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# DiagnosticReport
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Claim
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# ExplanationOfBenefit
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Encounter
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Observation
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Immunization
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# Claim
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# ExplanationOfBenefit
# ---------------------------------------------------------------

# %% [markdown]
# ## Check the collection

# %%
from pymilvus import Collection, utility

print(milvus_client.list_collections())
milvus_client.get_collection_stats(collection_name)
# Out:
# ['my_fhir_collection']
# {'row_count': 38}

# %%
collection = milvus_client.Collection(collection_name)  # Get an existing collection.

collection.schema                # Return the schema.CollectionSchema of the collection.
collection.description           # Return the description of the collection.
collection.name                  # Return the name of the collection.
collection.is_empty              # Return the boolean value that indicates if the collection is empty.
collection.num_entities          # Return the number of entities in the collection.
collection.primary_field         # Return the schema.FieldSchema of the primary key field.
collection.partitions            # Return the list[Partition] object.
collection.indexes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 collection = milvus_client.Collection(collection_name)  # Get an existing collection.
#       3 collection.schema                # Return the schema.CollectionSchema of the collection.
#       4 collection.description           # Return the description of the collection.
#
# AttributeError: 'MilvusClient' object has no attribute 'Collection'

# %% [markdown]
# # Build the RAG
# ## Retrieve data for a query
# Let's try a milvus query

# %%
question = "What is the patients name and surname"
question = "What conditions does the patient have?"

# %%
# Search for the question and return the top 3 matches
search_result = milvus_client.search(
    collection_name=collection_name,
    data=[
        embed_model.get_text_embedding(question)
    ], #questions becomes a vector as well
    limit = 3,
    search_params={"params": {}},
    output_fields=["id","resource"],
)

# %%
import json

retrieved_lines_with_distances = [
    (res["entity"]["resource"]["text"], res["distance"]) for res in search_result[0]
]
print(json.dumps(retrieved_lines_with_distances, indent=4))
# Out:
# [
#     [
#         "The type of information in this entry is patient. The name use for this patient is official. The name family for this patient is Kohler843. The name given for this patient is Cassy835. The telecom system for this patient is phone. The telecom value for this patient is 555-292-5994. The telecom use for this patient is home. The gender for this patient is female. The birth date for this patient is 2019-07-23. The address line for this patient is 949 Crist Burg Unit 59. The address city for this patient is Plymouth. The address state for this patient is Massachusetts. The address postalCode for this patient is 02360. The address country for this patient is US. The marital status for this patient is Never Married. The multiple birth boolean for this patient is False. The communication language for this patient is English.",
#         0.7696189284324646
#     ],
#     [
#         "The type of information in this entry is practitioner. The active for this practitioner is True. The name family for this practitioner is Schamberger479. The name given for this practitioner is Robena997. The name prefix for this practitioner is Dr.. The telecom system for this practitioner is email. The telecom value for this practitioner is Robena997.Schamberger479@example.com. The telecom use for this practitioner is work. The address line for this practitioner is 7 HERRING POND RD. The address city for this practitioner is CEDARVILLE. The address state for this practitioner is MA. The address postalCode for this practitioner is 02360-6903. The address country for this practitioner is US. The gender for this practitioner is female.",
#         0.6674193143844604
#     ],
#     [
#         "The type of information in this entry is claim. The status for this claim is active. The type of this claim is institutional. The use for this claim is claim. This claim was billable period start on 07/23/2019 at 00:19:26. This claim was billable period end on 07/23/2019 at 00:49:26. This claim was created on 07/23/2019 at 00:49:26. The priority for this claim is normal. The supporting info sequence for this claim is 1. The supporting info category of this claim is info. The procedure sequence for this claim is 1. The insurance for this claim is Anthem. The 2nd item for this claim is Well child visit (procedure). The 3rd item for this claim is Well child visit (procedure). The 4th item for this claim is Well child visit (procedure). The total for this claim is 129.16 USD.",
#         0.6421040892601013
#     ]
# ]

# %% [markdown]
# # RAG it up with LLM
# Convert the retrieved documents to String

# %%
from openai import OpenAI
client = OpenAI(
    api_key="lm-studio",
    base_url="http://localhost:1234/v1")

# %%
context = "\n".join(
    [line_with_distance[0] for line_with_distance in retrieved_lines_with_distances]
)

# %% [markdown]
# Define system and user prompts for the Lanage Model. This prompt is assembled with the retrieved documents from Milvus.

# %%
SYSTEM_PROMPT = """
Human: You are an AI assistant. You are able to find answers to the questions from the contextual passage snippets provided.
"""
USER_PROMPT = f"""
Use the following pieces of information enclosed in <context> tags to provide an answer to the question enclosed in <question> tags.
<context>
{context}
</context>
<question>
{question}
</question>
"""

# %% [markdown]
# Use OpenAI client to call local LLM to generate a response based on the prompts.
# I am using LM Studio you can get your list of models by runnnig: curl localhost:1234/v1/models

# %% [raw]
# ! curl http://localhost:1234/v1/models

# %%
response = client.chat.completions.create(
    model="granite-3.1-8b-instruct",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT},
    ],
)
print(response.choices[0].message.content)
# Out:
# The patient's given name is Cassy835 and the family name is Kohler843.
